# %%
#imported required libraries
import requests
from bs4 import BeautifulSoup
import csv

# %%
# to select the right table
r = requests.get(f"https://sis.ou.edu/ted/home/byOU?ou_subj_code=A+HI&ou_course=&stat_code=AL&sbgi_code=")
soup = BeautifulSoup(r.content.decode('utf8'),"lxml")
table = soup.find("table",{"summary":"OU matches"})

# %%
# find all rows
rows = table.findAll('tr')

# %%
# strip the header from rows
headers = rows[0]
header_text = []

# add the table header text to array
for th in headers.findAll('th'):
    header_text.append(th.text)

# %%
# declare list to add  row text array
row_text_array = []

# %%
# loop through rows and add row text to array
for row in rows[1:]:
    row_text = []
    # loop through the elements
    for row_element in row.findAll(['th', 'td']):
        # append the array with the elements inner text
        row_text.append(row_element.text.replace('\n', '').strip())
    # append the text array to the row text array
    row_text_array.append(row_text)

# %%
with open("table.csv", "w") as f:
    wr = csv.writer(f)
    wr.writerow(header_text)
    for row_text_single in row_text_array:
        wr.writerow(row_text_single)

# %%
#Let us check the saved csv file
import pandas
pd=pandas.read_csv("table.csv")

# %%
pd
# Out:
#    OUSubject  OUCourse                        OU Title  \
# 0       A HI      1113               Understanding Art
# 1       A HI      1113               Understanding Art
# 2       A HI      2213                    Global Art I
# 3       A HI      1999  Lower Division Transfer Credit
# 4       A HI      2213                    Global Art I
# 5       A HI      2213                    Global Art I
# 6       A HI      2223                  Global Art  II
# 7       A HI      2223                  Global Art  II
# 8       A HI      1113               Understanding Art
# 9       A HI      1113               Understanding Art
# 10      A HI      1113               Understanding Art
# 11      A HI      1113               Understanding Art
# 12      A HI      1999  Lower Division Transfer Credit
# 13      A HI      1113               Understanding Art
# 14      A HI      1999  Lower Division Transfer Credit
# 15      A HI      1113               Understanding Art
# 16      A HI      2213                    Global Art I
# 17      A HI      1113               Understanding Art
# 18      A HI      1113               Understanding Art
# 19      A HI      1113               Understanding Art
# 20      A HI      1113               Understanding Art
# 21      A HI      1113               Understanding Art
# 22      A HI      1113               Understanding Art
# 23      A HI      1113               Understanding Art
# 24      A HI      1113               Understanding Art
# 25      A HI      1113               Understanding Art
# 26      A HI      1113               Understanding Art
# 27      A HI      2213                    Global Art I
# 28      A HI      1113               Understanding Art
# 29      A HI      1999  Lower Division Transfer Credit
# 30      A HI      1113               Understanding Art
# 31      A HI      1113               Understanding Art
# 32      A HI      1113               Understanding Art
# 33      A HI      1113               Understanding Art
# 34      A HI      1999  Lower Division Transfer Credit
# 35      A HI      3999  Upper Division Transfer Credit
# 36      A HI      1113               Understanding Art
# 37      A HI      1113               Understanding Art
# 38      A HI      1113               Understanding Art
# 39      A HI      2213                    Global Art I
# 40      A HI      2223                  Global Art  II
# 41      A HI      3999  Upper Division Transfer Credit
# 42      A HI      1113               Understanding Art
# 43      A HI      2213                    Global Art I
# 44      A HI      2223                  Global Art  II
# 45      A HI      1113               Understanding Art
# 46      A HI      2223                  Global Art  II
# 47      A HI      1113               Understanding Art
# 48      A HI      1113               Understanding Art
# 49      A HI      1999  Lower Division Transfer Credit
# 50      A HI      2213                    Global Art I
# 51      A HI      1999  Lower Division Transfer Credit
# 52      A HI      1113               Understanding Art
# 53      A HI      1113               Understanding Art
# 54      A HI      1999  Lower Division Transfer Credit
#
#               Transfer Institution TransferSubject  TransferCourse  \
# 0           Alabama A&M University             ART             101
# 1         Alabama State University             ART             131
# 2                Auburn University            ARTS            1710
# 3                Auburn University            ARTS            1720
# 4                Auburn University              AT             171
# 5                Auburn University              AT             172
# 6                Auburn University              AT             172
# 7                Auburn University              AT             173
# 8     Auburn University-Montgomery            VISU            1000
# 9    Bevill St Comm Coll - Sumiton             ART             100
# 10     Birmingham Southern College              AR             215
# 11     Birmingham Southern College             ARH             215
# 12     Birmingham Southern College             ARH             215
# 13  Biship State Community College             ART             100
# 14  Biship State Community College             ART             100
# 15       Calhoun Community College             ART             100
# 16       Calhoun Community College             ART             203
# 17  Chattahoochee Valley Comm Coll             ART             100
# 18   Enterprise-Ozark Comm College             ART             100
# 19   Enterprise-Ozark Comm College             ART             101
# 20     Faulkner State Comm College             ART             100
# 21             Faulkner University              AR            1331
# 22      Gadsden State Comm College             ART             100
# 23    Jefferson State Comm College             ART             100
# 24  Lawson State Community College             ART             100
# 25  Lurleen B Wallace Comm College             ART             100
# 26       Marion Military Institute             ART             100
# 27       Marion Military Institute             ART             203
# 28   Northwest-Shoals Comm College             ART             100
# 29   Northwest-Shoals Comm College             ART             100
# 30      Nw Shoals Cc-Phil Campbell             ART             100
# 31              Samford University             ART             200
# 32   Snead State Community College             ART             100
# 33  Southern Union St Comm College             ART             100
# 34  Southern Union St Comm College             ART             100
# 35             Spring Hill College             ARH             311
# 36     Trenholm State Tech College             ART             100
# 37      Troy State Univ-Montgomery             ART            1135
# 38                 Troy University             G S             133
# 39      Univ Of Alabama-Huntsville             ARH             100
# 40      Univ Of Alabama-Huntsville             ARH             101
# 41      Univ Of Alabama-Huntsville             ARH             320
# 42           University Of Alabama             ARH             151
# 43           University Of Alabama             ARH             152
# 44           University Of Alabama             ARH             153
# 45           University Of Alabama             ARH             252
# 46           University Of Alabama             ARH             253
# 47            University Of Mobile              AR             201
# 48     University Of North Alabama              AR             170
# 49     University Of South Alabama             ARH             100
# 50     University Of South Alabama             ARH             103
# 51     University Of South Alabama             ARH             113
# 52     University Of South Alabama             ARS             101
# 53  Wallace St Comm Col-Hanceville             ART             100
# 54  Wallace St Comm Col-Hanceville             ART             203
#
#                   Transfer Title  TransferHours          TransferLevel  \
# 0               ART APPRECIATION           3.00  Lower Division Course
# 1               ART APPRECIATION           0.00  Lower Division Course
# 2            INTRO ART HISTORY I           3.00         LOWER DIVISION
# 3              INTRO ART HIST II           3.00  Lower Division Course
# 4              HISTORY WORLD ART           2.00  Lower Division Course
# 5              HISTORY WORLD ART           2.00  Lower Division Course
# 6              HISTORY WORLD ART           2.00  Lower Division Course
# 7              HISTORY WORLD ART           2.00  Lower Division Course
# 8   ART APPRECIATION/VISUAL ARTS           3.00  Lower Division Course
# 9               ART APPRECIATION           3.00  Lower Division Course
# 10            SURVEY OF ART HIST           4.00                    NaN
# 11                   ART HISTORY           4.00         LOWER DIVISION
# 12                   ART HISTORY           4.00         LOWER DIVISION
# 13              ART APPRECIATION           3.33  Lower Division Course
# 14              ART APPRECIATION           3.33  Lower Division Course
# 15              ART APPRECIATION           3.00  Lower Division Course
# 16                 ART HISTORY I           3.00         LOWER DIVISION
# 17              ART APPRECIATION           3.00  Lower Division Course
# 18              ART APPRECIATION           3.00  Lower Division Course
# 19                    ART APPREC           2.00  Lower Division Course
# 20              ART APPRECIATION           3.00  Lower Division Course
# 21              ART APPRECIATION           3.00  Lower Division Course
# 22              ART APPRECIATION           3.00  Lower Division Course
# 23              ART APPRECIATION           3.33  Lower Division Course
# 24              ART APPRECIATION           3.00  Lower Division Course
# 25              ART APPRECIATION           3.00         LOWER DIVISION
# 26              ART APPRECIATION           3.00         LOWER DIVISION
# 27                 ART HISTORY I           3.00         LOWER DIVISION
# 28              ART APPRECIATION           3.33  Lower Division Course
# 29              ART APPRECIATION           3.33  Lower Division Course
# 30              ART APPRECIATION           3.00  Lower Division Course
# 31              ART APPRECIATION           2.00  Lower Division Course
# 32              ART APPRECIATION           3.00  Lower Division Course
# 33              ART APPRECIATION           3.33  Lower Division Course
# 34              ART APPRECIATION           3.33  Lower Division Course
# 35           RENAISSANCE-MOD ART           3.00         UPPER DIVISION
# 36              ART APPRECIATION           3.00         LOWER DIVISION
# 37              ART APPRECIATION           3.00         LOWER DIVISION
# 38           GEN STDY VISUAL ART           2.00  Lower Division Course
# 39           ARH SURV:ANC/RENAIS           3.00                    NaN
# 40           ARH SURV:RENAIS/MOD           3.00                    NaN
# 41        INTL ART THRU POLITICS           3.00         UPPER DIVISION
# 42          INTRO TO VISUAL ARTS           3.00         LOWER DIVISION
# 43               SURVEY OF ART I           0.00                    NaN
# 44              SURVEY OF ART II           0.00                    NaN
# 45                  ART SURVEY I           3.00  Lower Division Course
# 46              SURVEY OF ART II           3.00  Lower Division Course
# 47              ART APPRECIATION           3.00         LOWER DIVISION
# 48              ART APPRECIATION           3.00         LOWER DIVISION
# 49                 SURVEY OF ART           3.00         LOWER DIVISION
# 50                 ART HISTORY I           3.00  Lower Division Course
# 51                  MEDIEVAL ART           2.67  Lower Division Course
# 52              ART APPRECIATION           3.00  Lower Division Course
# 53              ART APPRECIATION           3.00  Lower Division Course
# 54                 ART HISTORY I           3.00         LOWER DIVISION
#
#     OUCredits               Gen. Ed.  Pass
# 0        3.00  Gen Ed-Artistic Forms   NaN
# 1        0.00  Gen Ed-Artistic Forms   NaN
# 2        3.00  Gen Ed-Artistic Forms   NaN
# 3        3.00                    NaN   NaN
# 4        2.00  Gen Ed-Artistic Forms   NaN
# 5        1.00  Gen Ed-Artistic Forms   NaN
# 6        1.00  Gen Ed-Artistic Forms   NaN
# 7        2.00  Gen Ed-Artistic Forms   NaN
# 8        3.00  Gen Ed-Artistic Forms   NaN
# 9        3.00  Gen Ed-Artistic Forms   NaN
# 10       4.00  Gen Ed-Artistic Forms   NaN
# 11       3.00  Gen Ed-Artistic Forms   NaN
# 12       1.00                    NaN   NaN
# 13       3.00  Gen Ed-Artistic Forms   NaN
# 14       0.33                    NaN   NaN
# 15       3.00  Gen Ed-Artistic Forms   NaN
# 16       3.00  Gen Ed-Artistic Forms   NaN
# 17       3.00  Gen Ed-Artistic Forms   NaN
# 18       3.00  Gen Ed-Artistic Forms   NaN
# 19       2.00  Gen Ed-Artistic Forms   NaN
# 20       3.00  Gen Ed-Artistic Forms   NaN
# 21       3.00  Gen Ed-Artistic Forms   NaN
# 22       3.00  Gen Ed-Artistic Forms   NaN
# 23       3.33  Gen Ed-Artistic Forms   NaN
# 24       3.00  Gen Ed-Artistic Forms   NaN
# 25       3.00  Gen Ed-Artistic Forms   NaN
# 26       3.00  Gen Ed-Artistic Forms   NaN
# 27       3.00  Gen Ed-Artistic Forms   NaN
# 28       3.00  Gen Ed-Artistic Forms   NaN
# 29       0.33                    NaN   NaN
# 30       3.00  Gen Ed-Artistic Forms   NaN
# 31       2.00  Gen Ed-Artistic Forms   NaN
# 32       3.00  Gen Ed-Artistic Forms   NaN
# 33       3.00  Gen Ed-Artistic Forms   NaN
# 34       0.33                    NaN   NaN
# 35       3.00                    NaN   NaN
# 36       3.00  Gen Ed-Artistic Forms   NaN
# 37       3.00  Gen Ed-Artistic Forms   NaN
# 38       2.00  Gen Ed-Artistic Forms   NaN
# 39       3.00  Gen Ed-Artistic Forms   NaN
# 40       3.00  Gen Ed-Artistic Forms   NaN
# 41       3.00                    NaN   NaN
# 42       3.00  Gen Ed-Artistic Forms   NaN
# 43       0.00  Gen Ed-Artistic Forms   NaN
# 44       0.00  Gen Ed-Artistic Forms   NaN
# 45       3.00  Gen Ed-Artistic Forms   NaN
# 46       3.00  Gen Ed-Artistic Forms   NaN
# 47       3.00  Gen Ed-Artistic Forms   NaN
# 48       3.00  Gen Ed-Artistic Forms   NaN
# 49       3.00                    NaN   NaN
# 50       3.00  Gen Ed-Artistic Forms   NaN
# 51       2.67                    NaN   NaN
# 52       3.00  Gen Ed-Artistic Forms   NaN
# 53       3.00  Gen Ed-Artistic Forms   NaN
# 54       3.00                    NaN   NaN
